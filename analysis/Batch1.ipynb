# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('data25.csv')
df
# Out:
#      scnearioID    V  wireGauge  turns  radius  wireGauge_car  turns_car  \
# 0             1   96          8    230     1.5             12        410
# 1             2   96          8    230     1.5             12        570
# 2             3   96          8    230     1.5             12        410
# 3             4   96          8    230     1.5             12        570
# 4             5  600          8    230     1.5             12        410
# ..          ...  ...        ...    ...     ...            ...        ...
# 251         252   96          8    320     2.0             12        570
# 252         253  600          8    320     2.0             12        410
# 253         254  600          8    320     2.0             12        570
# 254         255  600          8    320     2.0             12        410
# 255         256  600          8    320     2.0             12        570
#
#      radius_car  height  spacing  velocity  totCharge
# ...

# %%
# voltage
plt.figure(figsize=(12,9))
for i in range(len(df)) : 
      for j in range(i, len(df)) :
            if(df['wireGauge'][i] == df['wireGauge'][j] and
               df['turns'][i] == df['turns'][j] and 
               df['radius'][i] == df['radius'][j] and 
               df['wireGauge_car'][i] == df['wireGauge_car'][j] and
               df['turns_car'][i] == df['turns_car'][j] and 
               df['radius_car'][i] == df['radius_car'][j] and 
               df['height'][i] == df['height'][j] and 
               df['spacing'][i] == df['spacing'][j] and 
               df['velocity'][i] == df['velocity'][j]):
                        v = [float(df['V'][i]),float(df['V'][j])]
                        charge = [float(df['totCharge'][i]),float(df['totCharge'][j])]
                        plt.plot(v, charge,color='blue')
plt.title('Output Charge vs. Voltage')
plt.xlabel("Voltage [V]")
plt.ylabel("Output Charge [C]")
# Out:
# Text(0, 0.5, 'Output Charge [C]')

# %%
# height
plt.figure(figsize=(12,9))
for i in range(len(df)) : 
        for j in range(i, len(df)) :
                  if(df['wireGauge'][i] == df['wireGauge'][j] and
                    df['turns'][i] == df['turns'][j] and 
                    df['radius'][i] == df['radius'][j] and 
                    df['wireGauge_car'][i] == df['wireGauge_car'][j] and
                    df['turns_car'][i] == df['turns_car'][j] and 
                    df['radius_car'][i] == df['radius_car'][j] and 
                    df['V'][i] == df['V'][j] and 
                    df['spacing'][i] == df['spacing'][j] and 
                    df['velocity'][i] == df['velocity'][j]):
                              v = [float(df['height'][i]),float(df['height'][j])]
                              charge = [float(df['totCharge'][i]),float(df['totCharge'][j])]
                              plt.plot(v, charge, color='blue')
plt.title('Output Charge vs. Height')
plt.xlabel("Height [m]")
plt.ylabel("Output Charge [C]")
# Out:
# Text(0, 0.5, 'Output Charge [C]')

# %%
# turns
plt.figure(figsize=(12,9))
for i in range(len(df)) : 
        for j in range(i, len(df)) :
                  if(df['wireGauge'][i] == df['wireGauge'][j] and
                    df['V'][i] == df['V'][j] and 
                    df['radius'][i] == df['radius'][j] and 
                    df['wireGauge_car'][i] == df['wireGauge_car'][j] and
                    df['turns_car'][i] == df['turns_car'][j] and 
                    df['radius_car'][i] == df['radius_car'][j] and 
                    df['height'][i] == df['height'][j] and 
                    df['spacing'][i] == df['spacing'][j] and 
                    df['velocity'][i] == df['velocity'][j]):
                            x = [float(df['turns'][i]),float(df['turns'][j])]
                            charge = [float(df['totCharge'][i]),float(df['totCharge'][j])]
                            plt.plot(x, charge,color='blue')
plt.title('Output Charge vs. Turns')
plt.xlabel("Turns")
plt.ylabel("Output Charge [C]")
# Out:
# Text(0, 0.5, 'Output Charge [C]')

# %%
# radius
plt.figure(figsize=(12,9))
for i in range(len(df)) : 
        for j in range(i, len(df)) :
                  if(df['wireGauge'][i] == df['wireGauge'][j] and
                    df['V'][i] == df['V'][j] and 
                    df['turns'][i] == df['turns'][j] and 
                    df['wireGauge_car'][i] == df['wireGauge_car'][j] and
                    df['turns_car'][i] == df['turns_car'][j] and 
                    df['radius_car'][i] == df['radius_car'][j] and 
                    df['height'][i] == df['height'][j] and 
                    df['spacing'][i] == df['spacing'][j] and 
                    df['velocity'][i] == df['velocity'][j]):
                              x = [float(df['radius'][i]),float(df['radius'][j])]
                              charge = [float(df['totCharge'][i]),float(df['totCharge'][j])]
                              plt.plot(x, charge,color='blue')
plt.title('Output Charge vs. Radius')
plt.xlabel("Radius [m]")
plt.ylabel("Output Charge [C]")
# Out:
# Text(0, 0.5, 'Output Charge [C]')

# %%
#turns(car)
plt.figure(figsize=(12,9))
for i in range(len(df)) : 
        for j in range(i, len(df)) :
                  if(df['wireGauge'][i] == df['wireGauge'][j] and
                    df['turns'][i] == df['turns'][j] and 
                    df['radius'][i] == df['radius'][j] and 
                    df['wireGauge_car'][i] == df['wireGauge_car'][j] and
                    df['V'][i] == df['V'][j] and 
                    df['radius_car'][i] == df['radius_car'][j] and 
                    df['height'][i] == df['height'][j] and 
                    df['spacing'][i] == df['spacing'][j] and 
                    df['velocity'][i] == df['velocity'][j]):
                            x = [float(df['turns_car'][i]),float(df['turns_car'][j])]
                            charge = [float(df['totCharge'][i]),float(df['totCharge'][j])]
                            plt.plot(x, charge,color='blue')
plt.title('Output Charge vs. Turns (car)')
plt.xlabel("Turns_car")
plt.ylabel("Output Charge [C]")
# Out:
# Text(0, 0.5, 'Output Charge [C]')

# %%
# radius(car)
plt.figure(figsize=(12,9))
for i in range(len(df)) : 
        for j in range(i, len(df)) :
                if(df['wireGauge'][i] == df['wireGauge'][j] and
                  df['turns'][i] == df['turns'][j] and 
                  df['radius'][i] == df['radius'][j] and 
                  df['wireGauge_car'][i] == df['wireGauge_car'][j] and
                  df['turns_car'][i] == df['turns_car'][j] and 
                  df['V'][i] == df['V'][j] and 
                  df['height'][i] == df['height'][j] and 
                  df['spacing'][i] == df['spacing'][j] and 
                  df['velocity'][i] == df['velocity'][j]):
                          x = [float(df['radius_car'][i]),float(df['radius_car'][j])]
                          charge = [int(df['totCharge'][i]),int(df['totCharge'][j])]
                          plt.plot(x, charge,color='blue')
plt.title('Output Charge vs. Radius(car)')
plt.xlabel("Radius (Car) [m]")
plt.ylabel("Output Charge [C]")
# Out:
# Text(0, 0.5, 'Output Charge [C]')

# %%
# radius(car)
plt.figure(figsize=(12,9))
for i in range(len(df)) : 
        for j in range(i, len(df)) :
                  if(df['wireGauge'][i] == df['wireGauge'][j] and
                    df['turns'][i] == df['turns'][j] and 
                    df['radius'][i] == df['radius'][j] and 
                    df['wireGauge_car'][i] == df['wireGauge_car'][j] and
                    df['turns_car'][i] == df['turns_car'][j] and 
                    df['V'][i] == df['V'][j] and 
                    df['height'][i] == df['height'][j] and 
                    df['spacing'][i] == df['spacing'][j] and 
                    df['velocity'][i] == df['velocity'][j]):
                            x = [float(df['radius_car'][i]),float(df['radius_car'][j])]
                            charge = [float(df['totCharge'][i]),float(df['totCharge'][j])]
                            plt.plot(x, charge,color='blue')
plt.title('Output Charge vs. Radius(car)')
plt.xlabel("Radius (Car) [m]")
plt.ylabel("Output Charge [C]")
# Out:
# Text(0, 0.5, 'Output Charge [C]')

# %%
# spacing
plt.figure(figsize=(12,9))
for i in range(len(df)) : 
        for j in range(i, len(df)) :
                  if(df['wireGauge'][i] == df['wireGauge'][j] and
                    df['turns'][i] == df['turns'][j] and 
                    df['radius'][i] == df['radius'][j] and 
                    df['wireGauge_car'][i] == df['wireGauge_car'][j] and
                    df['turns_car'][i] == df['turns_car'][j] and 
                    df['V'][i] == df['V'][j] and 
                    df['radius_car'][i] == df['radius_car'][j] and 
                    df['height'][i] == df['height'][j] and 
                    df['velocity'][i] == df['velocity'][j]):
                            x = [float(df['spacing'][i]),float(df['spacing'][j])]
                            charge = [float(df['totCharge'][i]),float(df['totCharge'][j])]
                            plt.plot(x, charge,color='blue')
plt.title('Output Charge vs. Spacing')
plt.xlabel("Spacing [m]")
plt.ylabel("Output Charge [C]")
# Out:
# Text(0, 0.5, 'Output Charge [C]')

# %%
# velocity
plt.figure(figsize=(12,9))
for i in range(len(df)) : 
        for j in range(i, len(df)) :
                  if(df['wireGauge'][i] == df['wireGauge'][j] and
                    df['turns'][i] == df['turns'][j] and 
                    df['radius'][i] == df['radius'][j] and 
                    df['wireGauge_car'][i] == df['wireGauge_car'][j] and
                    df['turns_car'][i] == df['turns_car'][j] and 
                    df['V'][i] == df['V'][j] and 
                    df['radius_car'][i] == df['radius_car'][j] and 
                    df['height'][i] == df['height'][j] and 
                    df['spacing'][i] == df['spacing'][j]):
                            x = [float(df['velocity'][i]),float(df['velocity'][j])]
                            charge = [float(df['totCharge'][i]),float(df['totCharge'][j])]
                            plt.plot(x, charge,color='blue')
plt.title('Output Charge vs. Velocity')
plt.xlabel("Velocity [m/s]")
plt.ylabel("Output Charge [C]")
# Out:
# Text(0, 0.5, 'Output Charge [C]')
